# %%
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/user/Downloads/new_database_results.csv')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Downloads\\cervitester (2)\\cervitester'

# %%
selected_columns = [
   'ID','Kerne_A', 'Cyto_A', 'K/C', 'KerneShort', 'CytoShort', 'KerneLong',
    'CytoLong', 'KerneElong', 'KerneRund', 'CytoRund', 'CytoElong',
    'KernePeri', 'CytoPeri', 'Class'
]

# %%
df= df[selected_columns]

# %%
df.head()
# Out:
#                             ID  Kerne_A     Cyto_A       K/C  KerneShort  \
# 0  153958345-153958392-001.BMP  803.500  27804.125  0.028087   29.832191
# 1  153960256-153960295-002.BMP  610.125  18067.875  0.032665   25.319871
# 2  157181281-157181308-001.BMP  990.375  79029.875  0.012377   33.552901
# 3  157181387-157181418-001.BMP  554.500  98941.000  0.005573   23.799254
# 4  157181525-157181540-001.BMP  636.375  99663.250  0.006345   25.946189
#
#     CytoShort  KerneLong    CytoLong  KerneElong  KerneRund  CytoRund  \
# 0  181.574886  34.828150  242.043385    0.856554   0.843403  0.604273
# 1  171.108766  30.805844  197.570241    0.821918   0.818583  0.589351
# 2  290.250246  38.327536  355.803316    0.875425   0.858397  0.794843
# 3  327.983056  29.832868  425.619548    0.797753   0.793271  0.695414
# 4  418.494540  31.256999  344.193260    0.830092   0.829332  1.071126
#
#    CytoElong  KernePeri  CytoPeri  Class
# 0   0.750175    101.375   673.500      1
# 1   0.866065     85.250   597.000      1
# 2   0.815760    111.750  1059.125      1
# 3   0.770601     81.000  1264.500      1
# 4   1.215871     87.875  1250.625      1

# %%
df['Class'] = df['Class'].apply(lambda x: 0 if x in [1, 2, 3] else 1)

# %%
df
# Out:
#                               ID   Kerne_A     Cyto_A       K/C  KerneShort  \
# 0    153958345-153958392-001.BMP   803.500  27804.125  0.028087   29.832191
# 1    153960256-153960295-002.BMP   610.125  18067.875  0.032665   25.319871
# 2    157181281-157181308-001.BMP   990.375  79029.875  0.012377   33.552901
# 3    157181387-157181418-001.BMP   554.500  98941.000  0.005573   23.799254
# 4    157181525-157181540-001.BMP   636.375  99663.250  0.006345   25.946189
# ..                           ...       ...        ...       ...         ...
# 912  153831471-153831486-004.BMP  3708.625   1985.000  0.651364   61.664414
# 913  153916114-153916150-001.BMP  2813.750   2245.875  0.556118   47.320650
# 914  153916114-153916167-001.BMP  2551.875   2153.875  0.542289   46.259154
# 915  153916114-153916167-002.BMP  2064.500   2256.250  0.477811   42.776006
# 916  153916569-153916586-001.BMP  1651.125   2210.875  0.427531   43.972527
#
#       CytoShort  KerneLong    CytoLong  KerneElong  KerneRund  CytoRund  \
# 0    181.574886  34.828150  242.043385    0.856554   0.843403  0.604273
# 1    171.108766  30.805844  197.570241    0.821918   0.818583  0.589351
# 2    290.250246  38.327536  355.803316    0.875425   0.858397  0.794843
# 3    327.983056  29.832868  425.619548    0.797753   0.793271  0.695414
# 4    418.494540  31.256999  344.193260    0.830092   0.829332  1.071126
# ..          ...        ...         ...         ...        ...       ...
# 912   68.965722  82.219219  101.833197    0.750000   0.698516  0.243720
dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
x_numeric = x.drop(columns=['ID'])
scaler = StandardScaler()


x= scaler.fit_transform(x_numeric)

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

log_reg = LogisticRegression()
log_reg.fit(xtrain, ytrain)

y_pred = log_reg.predict(xtest)
accuracy = accuracy_score(ytest, y_pred)
print(f'Logistic Regression Accuracy: {accuracy:.2f}')
# Out:
# Logistic Regression Accuracy: 0.96

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm=confusion_matrix(y_pred,ytest)
cm
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

svm = SVC( kernel='rbf')
svm.fit(xtrain, ytrain)
# Out:
# SVC()

# %%
# Make predictions and evaluate the model
y_pred = svm.predict(xtest)
accuracy = accuracy_score(ytest, y_pred)
print(f'SVM Accuracy: {accuracy:.2f}')
# Out:
# SVM Accuracy: 0.96

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm=confusion_matrix(y_pred,ytest)
cm
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


rf = RandomForestClassifier()
rf.fit(xtrain, ytrain)

# Make predictions and evaluate the model
y_pred = rf.predict(xtest)
accuracy = accuracy_score(ytest, y_pred)
print(f'Random Forest Accuracy: {accuracy:.2f}')
# Out:
# Random Forest Accuracy: 0.96

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm=confusion_matrix(y_pred,ytest)
cm
# Out:
# array([[ 54,   6],
#        [  4, 166]])

# %% [markdown]
# ## ARTIFICIAL NEURAL NETWORK

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score

# %%
model = Sequential()
model.add(Dense(16, input_dim=xtrain.shape[1], activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(xtrain, ytrain, epochs=20, batch_size=10, verbose=1)

# Make predictions and evaluate the model
y_pred = (model.predict(xtest) > 0.5).astype("int32")
accuracy = accuracy_score(ytest, y_pred)
print(f'ANN Accuracy: {accuracy:.2f}')
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7382 - loss: 0.5706
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8400 - loss: 0.4062
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8751 - loss: 0.3162
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9191 - loss: 0.2400
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9137 - loss: 0.2216
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9095 - loss: 0.2139
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9283 - loss: 0.1964
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9160 - loss: 0.1973
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9079 - loss: 0.2269
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9179 - loss: 0.2216
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9245 - loss: 0.1903
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9030 - loss: 0.2297
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9170 - loss: 0.2006
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9057 - loss: 0.2065
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9183 - loss: 0.1908
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9171 - loss: 0.1833
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9294 - loss: 0.1833
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9275 - loss: 0.1894
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9232 - loss: 0.1762
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9243 - loss: 0.1698
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ANN Accuracy: 0.96

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm=confusion_matrix(y_pred,ytest)
cm
# Out:
# array([[ 52,   4],
#        [  6, 168]])

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from skimage.measure import label, regionprops
from skimage.morphology import closing, square





img_path = r"C:\Users\user\Downloads\cervitester (2)\cervitester\smear2005\New database pictures\normal_superficiel\153958345-153958392-001-d.bmp"
img = Image.open(img_path)






img_rgb = img.convert("RGB")
img_rgb_array = np.array(img_rgb)




nucleus_color = np.array([0, 0, 255])  
cytoplasm_color = np.array([0, 0, 128])   









# Calculate the distance from each pixel to the nucleus and cytoplasm colors
nucleus_mask = np.all(np.abs(img_rgb_array - nucleus_color) < 50, axis=-1)
cytoplasm_mask = np.all(np.abs(img_rgb_array - cytoplasm_color) < 50, axis=-1)









# Apply morphological closing to fill small holes
nucleus_mask = closing(nucleus_mask, square(3))
cytoplasm_mask = closing(cytoplasm_mask, square(3))




# Label the regions
nucleus_label = label(nucleus_mask)
cytoplasm_label = label(cytoplasm_mask)









# Plot the processed masks
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].imshow(nucleus_mask, cmap='gray')
ax[0].set_title('Nucleus Mask')
ax[0].axis('off')
ax[1].imshow(cytoplasm_mask, cmap='gray')
ax[1].set_title('Cytoplasm Mask')
ax[1].axis('off')
plt.show()

# %%
import numpy as np
from skimage.measure import label, regionprops

# Assuming nucleus_mask and cytoplasm_mask are the masks you have
# Label the regions
nucleus_label = label(nucleus_mask)
cytoplasm_label = label(cytoplasm_mask)

# Get properties of the labeled regions
nucleus_regions = regionprops(nucleus_label)
cytoplasm_regions = regionprops(cytoplasm_label)

def calculate_properties(region, region_type):
    properties = {}
    properties[f"{region_type} Area"] = region.area
    properties[f"{region_type} Perimeter"] = region.perimeter
    properties[f"{region_type} Major Axis Length"] = region.major_axis_length
    properties[f"{region_type} Minor Axis Length"] = region.minor_axis_length
    
    # Calculate Elongation based on bounding box dimensions
    properties[f"{region_type} Elongation"] = region.minor_axis_length / region.major_axis_length
    
    # Calculate Roundness
    if region.major_axis_length > 0:  # Assuming major_axis_length is the longest diameter
        circle_area = (np.pi / 4) * (region.major_axis_length ** 2)
        roundness = region.area / circle_area
    else:
        roundness = np.nan  # Handle division by zero

    properties[f"{region_type} Roundness"] = roundness

    return properties

# Calculate properties for the largest regions
nucleus_properties = calculate_properties(max(nucleus_regions, key=lambda x: x.area), "Nucleus") if nucleus_regions else {}
cytoplasm_properties = calculate_properties(max(cytoplasm_regions, key=lambda x: x.area), "Cytoplasm") if cytoplasm_regions else {}

# Calculate the additional combined properties
if nucleus_properties and cytoplasm_properties:
    combined_properties = {
        "Nucleus/Cytoplasm Area Ratio": nucleus_properties["Nucleus Area"] / cytoplasm_properties["Cytoplasm Area"]
    }
    
    combined_properties.update(nucleus_properties)
    combined_properties.update(cytoplasm_properties)
else:
    combined_properties = {}

# Print the properties
for prop, value in combined_properties.items():
    print(f"{prop}: {value}")
# Out:
# Nucleus/Cytoplasm Area Ratio: 0.028738939644629882
# Nucleus Area: 799.0
# Nucleus Perimeter: 106.91168824543142
# Nucleus Major Axis Length: 34.78541072320451
# Nucleus Minor Axis Length: 29.3104586670345
# Nucleus Elongation: 0.842607807631324
# Nucleus Roundness: 0.840741773995951
# Cytoplasm Area: 27802.0
# Cytoplasm Perimeter: 825.1097397793778
# Cytoplasm Major Axis Length: 228.6054630456633
# Cytoplasm Minor Axis Length: 173.5580466435944
# Cytoplasm Elongation: 0.7592034080520931
# Cytoplasm Roundness: 0.67734970869723

# %%
combined_feature_vector = list(combined_properties.values())

combined_feature_vector
# Out:
# [np.float64(0.028738939644629882),
#  np.float64(799.0),
#  np.float64(106.91168824543142),
#  34.78541072320451,
#  29.3104586670345,
#  0.842607807631324,
#  np.float64(0.840741773995951),
#  np.float64(27802.0),
#  np.float64(825.1097397793778),
#  228.6054630456633,
#  173.5580466435944,
#  0.7592034080520931,
#  np.float64(0.67734970869723)]

# %%
ypren=log_reg.predict([combined_feature_vector])

# %%
ypren
# Out:
# array([0])

# %%
df.to_csv('new_shape.csv', index=False)
